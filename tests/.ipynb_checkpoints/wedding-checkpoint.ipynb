# %% [markdown]
# # Playground

# %%
import keras
from keras.layers import Input, Dense, Activation, Dropout
from keras.models import Model, Sequential
import time

import numpy as np

from forwardThinking.datasets import load_mnist

# %%
x_train, y_train, x_test, y_test = load_mnist()
input_dim = 784
hidden_dim = 100
output_dim = 10

# %%
model = Sequential()
model.add(Dense(hidden_dim, input_shape=(input_dim,), name='dense_0'))
model.add(Dense(output_dim, name='output_dense'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
h = model.fit(x_train, y_train, epochs=2, verbose=False, validation_data=(x_test, y_test))

# %%
for l in model.layers:
    print l.get_weights()[0].shape
# Out:
# (784, 100)
# (100, 10)

# %%
l.output_shape
# Out:
# (None, 10)

# %%
l.
# Out:
# 'output_dense'

# %%
frozen_weights = model.get_layer('init_dense').get_weights()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0 (Dense)              (None, 100)               78500
# _________________________________________________________________
# output_dense (Dense)         (None, 10)                1010
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import backend as K

def prelu_init(shape, dtype=None):
    return -1

# %%
def extend(model, hidden_dim, output_dim):
    new_model = Sequential()
    for i, l in enumerate(model.layers[:-1]):
        if "dense" in l.name:
            new_model.add(Dense(l.output_shape[1], input_shape=(l.input_shape[1],), name="dense_{}".format(i)))
            old_weights = model.get_layer("dense_{}".format(i)).get_weights()
            new_model.get_layer('dense_{}'.format(i)).set_weights(old_weights)
        
    # new layer
    new_model.add(Dense(hidden_dim, activation='linear',
                        kernel_initializer = keras.initializers.Identity(gain=1.0), 
                        bias_initializer='zeros', name="dense_{}".format(i+1)))
    new_model.add(keras.layers.advanced_activations.PReLU(alpha_initializer=prelu_init, alpha_regularizer=None, alpha_constraint=None, shared_axes=None))
    
    # same output layer
    old_weights = model.get_layer("output_dense").get_weights()
    new_model.add(Dense(output_dim, name="output_dense"))
    new_model.get_layer("output_dense").set_weights(old_weights)

    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return new_model

# %%
nmodel = extend(model, hidden_dim, output_dim)
nmodel.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-f3eb374d465f> in <module>()
# ----> 1 nmodel = extend(model, hidden_dim, output_dim)
#       2 nmodel.summary()
#
# <ipython-input-68-e2f99b3e85a4> in extend(model, hidden_dim, output_dim)
#      18
#      19
# ---> 20     new_model.get_layer("output_dense").set_weights(old_weights)
#      21
#      22
#
# AttributeError: 'NoneType' object has no attribute 'set_weights'

# %%
model.get_layer('output_dense').get_weights()
# Out:
# [array([[  2.21567065e-01,   1.93077981e-01,  -1.67552680e-01,
#            1.91902280e-01,   3.23892236e-02,   1.52583033e-01,
#            2.09375709e-01,   1.91509128e-02,   2.18602806e-01,
#            2.23774821e-01],
#         [  3.13456059e-02,  -1.22050323e-01,  -9.29899514e-03,
#           -1.73217952e-02,   1.36706978e-01,  -2.19975501e-01,
#           -1.87664837e-01,   1.42762363e-02,  -8.56010020e-02,
#            2.09949017e-01],
#         [ -1.76236436e-01,   1.26888573e-01,   7.06218183e-02,
#           -9.28208679e-02,  -1.88261762e-01,  -1.07255727e-02,
#            8.68860483e-02,  -1.03337750e-01,  -1.51271045e-01,
#           -1.83728695e-01],
#         [  7.62244463e-02,   1.87634617e-01,   1.60208941e-01,
#            2.27403551e-01,   3.66534591e-02,   9.11362469e-02,
